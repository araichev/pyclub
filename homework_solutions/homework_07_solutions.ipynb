# %%
from pathlib import Path

import pandas as pd
import pygal as pg
from highcharts import Highchart
import spectra

from IPython.core.display import HTML

DATA_DIR = Path('../data')
# %matplotlib inline

# %%
# Load data of Auckland transit delays
#
path = DATA_DIR/'auckland_transit_delays_20170217--20170226.csv'
delays = pd.read_csv(path, dtype={   
  'route_id': str,
  'route_short_name': str,
  'route_type': str,
  })
delays.T
# Out:
#                                                      0    \
# route_short_name                                     005
# delay_p000                                          -779
# delay_p010                                        -124.5
# delay_p025                                         30.25
# delay_p050                                           144
# delay_p075                                        376.25
# delay_p090                                         641.5
# delay_p100                                          1662
# end_delay_p000                                      -779
# end_delay_p010                                    -556.4
# end_delay_p025                                      -396
# end_delay_p050                                     -75.5
# end_delay_p075                                       310
# end_delay_p090                                     570.2
# end_delay_p100                                      1223
# num_delays                                          1526
# num_end_delays                                        92
# route_id                                       route_001
# route_long_name   Britomart To Pt Chevalier Via Westmere
# num_stop_times                                      2808
# num_trips                                            108
#
#                                          1                    2    \
# route_short_name                         007                  008
# delay_p000                             -1510                -1787
# delay_p010                               -65                  -53
# delay_p025                                66                   46
# delay_p050                               221                  176
# delay_p075                               424                  369
# delay_p090                               677                  585
# delay_p100                              1781                 1656
# end_delay_p000                         -1510                 -907
# end_delay_p010                          -611               -287.2
# end_delay_p025                       -360.25               -104.5
# end_delay_p050                         -76.5                   94
# end_delay_p075                        268.75                  339
# end_delay_p090                         721.5                557.6
# end_delay_p100                          1781                 1347
# num_delays                             20841                14617
# num_end_delays                           466                  447
# route_id                           route_002            route_003
# route_long_name   Pt Chevalier To Glen Innes  Otahuhu To New Lynn
# num_stop_times                         47186                27592
# num_trips                                598                  472
#
#                                                                 3    \
# route_short_name                                                009
# delay_p000                                                    -1019
# delay_p010                                                      -16
# delay_p025                                                       70
# delay_p050                                                      174
# delay_p075                                                      315
# delay_p090                                                      502
# delay_p100                                                     1738
# end_delay_p000                                                -1019
# end_delay_p010                                                 -458
# end_delay_p025                                                 -282
# end_delay_p050                                                  -75
# end_delay_p075                                                  104
# end_delay_p090                                                304.8
# end_delay_p100                                                 1133
# num_delays                                                    12256
# num_end_delays                                                  449
# route_id                                                  route_004
# route_long_name   Sylvia Park To New Lynn (No Stop On Donavon St...
# num_stop_times                                                25750
# num_trips                                                       458
#
#                                                      4    \
# route_short_name                                     010
# delay_p000                                         -1432
# delay_p010                                          -225
# delay_p025                                            17
# delay_p050                                           175
# delay_p075                                           356
# delay_p090                                           561
# delay_p100                                          1730
# end_delay_p000                                     -1424
# end_delay_p010                                      -708
# end_delay_p025                                   -411.25
# end_delay_p050                                    -165.5
# end_delay_p075                                        83
# end_delay_p090                                       231
# end_delay_p100                                      1499
# num_delays                                          5929
# num_end_delays                                       156
# route_id                                       route_005
# route_long_name   Wynyard Quarter To Onehunga Via Unitec
# num_stop_times                                     11772
# num_trips                                            216
#
#                                    5    \
# route_short_name                   011
# delay_p000                        -334
# delay_p010                          -7
# delay_p025                          41
# delay_p050                       114.5
# delay_p075                      219.25
# delay_p090                         330
# delay_p100                        1070
# end_delay_p000                    -334
# end_delay_p010                  -191.7
# end_delay_p025                    -107
# end_delay_p050                    21.5
# end_delay_p075                  133.25
# end_delay_p090                   288.9
# end_delay_p100                    1016
# num_delays                        1016
# num_end_delays                      68
# route_id                     route_006
# route_long_name   St Lukes to Onehunga
# num_stop_times                    2196
# num_trips                           72
#
#                                                       6    \
# route_short_name                                      020
# delay_p000                                          -1431
# delay_p010                                           -218
# delay_p025                                            -65
# delay_p050                                             39
# delay_p075                                            150
# delay_p090                                            337
# delay_p100                                           1768
# end_delay_p000                                       -903
# end_delay_p010                                     -390.9
# end_delay_p025                                    -240.75
# end_delay_p050                                        -72
# end_delay_p075                                        138
# end_delay_p090                                      381.6
# end_delay_p100                                       1685
# num_delays                                          12116
# num_end_delays                                        762
# route_id                                        route_007
# route_long_name   Britomart To Westmere Via Wellington St
# num_stop_times                                      25804
# num_trips                                             890
#
#                                             7                         8    \
# route_short_name                           020X                       027
# delay_p000                                -1177                      -379
# delay_p010                                  -30                     112.2
# delay_p025                                   36                     212.5
# delay_p050                                  117                       362
# delay_p075                                  275                     618.5
# delay_p090                                  759                       790
# delay_p100                                 1794                      1041
# end_delay_p000                            -1177                      -379
# end_delay_p010                           -467.5                      -153
# end_delay_p025                          -110.75                     177.5
# end_delay_p050                               20                       409
# end_delay_p075                              196                       635
# end_delay_p090                            705.3                       965
# end_delay_p100                             1383                      1041
# num_delays                                  681                       223
# num_end_delays                               52                        11
# route_id                              route_008                 route_009
# route_long_name   Britomart To Westmere Express  Stanmore Bay To Long Bay
# num_stop_times                             1320                       426
# num_trips                                    60                        12
#
#                                           9    \
# route_short_name                          030
# delay_p000                              -1106
# delay_p010                             -407.1
# delay_p025                               -149
# delay_p050                                 32
# delay_p075                                153
# delay_p090                              274.1
# delay_p100                               1800
# end_delay_p000                           -961
# end_delay_p010                           -641
# end_delay_p025                         -498.5
# end_delay_p050                           -325
# end_delay_p075                           -112
# end_delay_p090                            164
# end_delay_p100                           1735
# num_delays                               8380
# num_end_delays                            591
# route_id                            route_010
# route_long_name   Pt Chevalier To City Centre
# num_stop_times                          19610
# num_trips                                 666
#
#                                         ...                          \
# route_short_name                        ...
# delay_p000                              ...
# delay_p010                              ...
# delay_p025                              ...
# delay_p050                              ...
# delay_p075                              ...
# delay_p090                              ...
# delay_p100                              ...
# end_delay_p000                          ...
# end_delay_p010                          ...
# end_delay_p025                          ...
# end_delay_p050                          ...
# end_delay_p075                          ...
# end_delay_p090                          ...
# end_delay_p100                          ...
# num_delays                              ...
# num_end_delays                          ...
# route_id                                ...
# route_long_name                         ...
# num_stop_times                          ...
# num_trips                               ...
#
#                                                                 239  \
# route_short_name                                                986
# delay_p000                                                     -537
# delay_p010                                                     -116
# delay_p025                                                      -17
# delay_p050                                                     73.5
# delay_p075                                                      183
# delay_p090                                                    297.3
# delay_p100                                                     1011
# end_delay_p000                                                 -440
# end_delay_p010                                                -76.6
# end_delay_p025                                                  -14
# end_delay_p050                                                   75
# end_delay_p075                                                168.5
# end_delay_p090                                                328.4
# end_delay_p100                                                  748
# num_delays                                                     1478
# num_end_delays                                                   83
# route_id                                                  route_240
# route_long_name   Albany Station to HC Station via Albany Centre...
# num_stop_times                                                 3360
# num_trips                                                       120
#
#                                       240  \
# route_short_name                      987
# delay_p000                           -263
# delay_p010                           -157
# delay_p025                         -27.75
# delay_p050                             19
# delay_p075                             60
# delay_p090                          147.1
# delay_p100                            990
# end_delay_p000                       -263
# end_delay_p010                     -216.9
# end_delay_p025                     -205.5
# end_delay_p050                       -142
# end_delay_p075                        716
# end_delay_p090                      833.7
# end_delay_p100                        990
# num_delays                             90
# num_end_delays                         22
# route_id                        route_241
# route_long_name   Arkles Bay to The Plaza
# num_stop_times                        216
# num_trips                              36
#
#                                                                 241  \
# route_short_name                                                988
# delay_p000                                                     -696
# delay_p010                                                   -383.8
# delay_p025                                                     -153
# delay_p050                                                       48
# delay_p075                                                      111
# delay_p090                                                    179.6
# delay_p100                                                      500
# end_delay_p000                                                 -696
# end_delay_p010                                               -616.6
# end_delay_p025                                                 -557
# end_delay_p050                                                 -493
# end_delay_p075                                                 -418
# end_delay_p090                                               -230.4
# end_delay_p100                                                  271
# num_delays                                                      995
# num_end_delays                                                   73
# route_id                                                  route_242
# route_long_name   Gulf Harbour Ferry to The Plaza via Shakespear...
# num_stop_times                                                 2730
# num_trips                                                        84
#
#                                                                 242  \
# route_short_name                                               991X
# delay_p000                                                     -765
# delay_p010                                                   -370.6
# delay_p025                                                     -179
# delay_p050                                                       37
# delay_p075                                                      164
# delay_p090                                                      316
# delay_p100                                                      797
# end_delay_p000                                                 -765
# end_delay_p010                                               -574.6
# end_delay_p025                                              -383.25
# end_delay_p050                                               -241.5
# end_delay_p075                                                 -104
# end_delay_p090                                                145.6
# end_delay_p100                                                  474
# num_delays                                                      839
# num_end_delays                                                   44
# route_id                                                  route_243
# route_long_name   Waiwera to City Centre (Wellesley St) via HC S...
# num_stop_times                                                 1344
# num_trips                                                        48
#
#                                                                 243  \
# route_short_name                                               992X
# delay_p000                                                    -1754
# delay_p010                                                   -800.8
# delay_p025                                                     -472
# delay_p050                                                     -137
# delay_p075                                                       38
# delay_p090                                                      162
# delay_p100                                                     1296
# end_delay_p000                                                -1617
# end_delay_p010                                                 -919
# end_delay_p025                                               -649.5
# end_delay_p050                                               -399.5
# end_delay_p075                                                 -125
# end_delay_p090                                                  303
# end_delay_p100                                                  705
# num_delays                                                     2543
# num_end_delays                                                   66
# route_id                                                  route_244
# route_long_name   City Centre (Wellesley St) to Gulf Harbour via...
# num_stop_times                                                 5358
# num_trips                                                        90
#
#                                                          244  \
# route_short_name                                         CTY
# delay_p000                                             -1793
# delay_p010                                              -299
# delay_p025                                              -143
# delay_p050                                                 2
# delay_p075                                                78
# delay_p090                                               173
# delay_p100                                              1742
# end_delay_p000                                         -1793
# end_delay_p010                                        -549.5
# end_delay_p025                                       -406.75
# end_delay_p050                                          -240
# end_delay_p075                                        -33.75
# end_delay_p090                                           161
# end_delay_p100                                          1298
# num_delays                                             18483
# num_end_delays                                           486
# route_id                                           route_247
# route_long_name   City Link To Wynyard Quarter Via Greys Ave
# num_stop_times                                         25880
# num_trips                                               1294
#
#                                    245                          246  \
# route_short_name                   INN                          NEX
# delay_p000                       -1747                        -1357
# delay_p010                      -152.5                         -384
# delay_p025                         -12                         -198
# delay_p050                         123                          -33
# delay_p075                         332                           81
# delay_p090                         659                          211
# delay_p100                        1799                         1750
# end_delay_p000                   -1406                        -1357
# end_delay_p010                    -350                         -641
# end_delay_p025                    -173                         -438
# end_delay_p050                       0                         -208
# end_delay_p075                   252.5                          3.5
# end_delay_p090                     598                          184
# end_delay_p100                    1795                         1750
# num_delays                       37566                        19709
# num_end_delays                    1471                         2476
# route_id                     route_253                    route_265
# route_long_name   Inner Link Clockwise  Albany Station To Britomart
# num_stop_times                   60620                        23486
# num_trips                         1740                         2662
#
#                                                         247  \
# route_short_name                                        OUT
# delay_p000                                            -1792
# delay_p010                                             -130
# delay_p025                                                6
# delay_p050                                              136
# delay_p075                                              333
# delay_p090                                              627
# delay_p100                                             1798
# end_delay_p000                                        -1699
# end_delay_p010                                         -331
# end_delay_p025                                      -178.75
# end_delay_p050                                           -6
# end_delay_p075                                       204.25
# end_delay_p090                                        510.5
# end_delay_p100                                         1693
# num_delays                                            52909
# num_end_delays                                         1336
# route_id                                          route_267
# route_long_name   Outer Link Newmarket To CBD Anticlockwise
# num_stop_times                                        97414
# num_trips                                              1444
#
#                                                                 248
# route_short_name                                                SKY
# delay_p000                                                    -1268
# delay_p010                                                     -216
# delay_p025                                                      -44
# delay_p050                                                       91
# delay_p075                                                      286
# delay_p090                                                      547
# delay_p100                                                     1792
# end_delay_p000                                                -1242
# end_delay_p010                                               -547.4
# end_delay_p025                                                 -308
# end_delay_p050                                                 -8.5
# end_delay_p075                                                  296
# end_delay_p090                                                  573
# end_delay_p100                                                 1787
# num_delays                                                    12916
# num_end_delays                                                 1704
# route_id                                                  route_272
# route_long_name   International Airport To Downtown Via Dominion Rd
# num_stop_times                                                22520
# num_trips                                                      2220
#
# [21 rows x 249 columns]

# %% [markdown]
# # Problem 3

# %%
# python-highcharts box plot
#
f = delays.copy()    

# Only keep routes with a large enough fraction of delay samples
cond = f['num_delays']/f['num_stop_times'] >= 0.4
f = f[cond].copy()

# Convert to minutes
cols = ['delay_p{:03d}'.format(p) for p in [0, 10, 25, 50, 75, 90, 100]]
f[cols] /= 60

# Create name
f['name'] = f[['route_short_name', 'route_long_name']].apply(
  lambda x: ', '.join(x), axis=1) 

# Custom color routes
scale = spectra.scale(['#2b83ba', '#ffffbf', '#d7191c', '#d7191c'])
scale = scale.domain([0, 10, 20, 30])
scale = scale.colorspace('lch')
f['iqr'] = f[cols[4]] - f[cols[2]]
f['color'] = f['iqr'].map(lambda x: scale(abs(x)).hexcode)

# Plot
chart = Highchart()
N = f.shape[0]
options = {
    'chart': {
        'width': 650,
        'height': 15*N,
        'inverted': True,
    },
    'title': {
        'text': 'Box plots of stop delays',
    },
    'subtitle': {
        'text': 'Study period is 2017-02-17 to 2017-02-26',
    },
    'legend': {
        'enabled': False,
    },
    'plotOptions': {
        'boxplot': {
            'color': '#666'
        }
    },
    'xAxis': {
        'title': {
            'text': 'Route'
        },
        'type': 'category',
        'categories': f['name'].tolist(),
    },
    'yAxis': {
        'title': {
            'text': 'Delay (min)'
        },
        'opposite': True,
        'tickInterval': 5,
        'plotLines': [{
            'value': 0,
            'color': 'purple',
            'width': 2,
        }]    
    },
    'tooltip': {
        'valueDecimals': 1,
        'useHTML': True,
        'headerFormat': '''
           <b>{point.key}</b> 
           <table><tr><td>Percentile</td><td>Delay</td></tr>
           ''',
        'pointFormat': '''
            <tr>
              <td style="padding-right:0.5em">10th</td>
              <td style="text-align:right">{point.low} min</td>
            </tr>
            <tr>
              <td style="padding-right:0.5em">25th</td>
              <td style="text-align:right">{point.q1} min</td>
            </tr>
            <tr>
              <td style="padding-right:0.5em">50th</td>
              <td style="text-align:right">{point.median} min</td>
            </tr>
            <tr>
              <td style="padding-right:0.5em">75th</td>
              <td style="text-align:right">{point.q3} min</td>
            </tr>
            <tr>
              <td style="padding-right:0.5em">90th</td>
              <td style="text-align:right">{point.high} min</td>
            </tr>
            ''',
        'footerFormat' : '</table>'
    }
}
chart.set_dict_options(options)

# Central values
data = [{
    'fillColor': row['color'],
    'low': row[cols[1]],
    'q1': row[cols[2]],
    'median': row[cols[3]],
    'q3': row[cols[4]],
    'high': row[cols[5]],
    } for __, row in f.iterrows()]
chart.add_data_set(data, 'boxplot')

# Min values
opts = {
    'marker': {
        'fillColor': 'white',
        'lineWidth': 1,
        'lineColor': '#666',
        'radius': 2,
    },
    'tooltip': {
        'pointFormat': '''
            <tr>
              <td style="padding-right:0.5em">0th</td>
              <td style="text-align:right">{point.y} min</td>
            </tr>
            '''
    }
}
data = [{
    'y': row[cols[0]]    
    } for __, row in f.iterrows()]
chart.add_data_set(data, 'scatter', **opts)

# Max values
opts['tooltip']['pointFormat'] = '''
    <tr>
      <td style="padding-right:0.5em">100th</td>
      <td style="text-align:right">{point.y} min</td>
    </tr>
    '''
data = [{
    'y': row[cols[-1]]    
    } for __, row in f.iterrows()]
chart.add_data_set(data, 'scatter', **opts)    

chart
# Out:
# <iframe style="border:0;outline:none;overflow:hidden" srcdoc="&lt;!DOCTYPE html&gt; &lt;html lang=&quot;en&quot;&gt; &lt;head&gt; &lt;meta charset=&quot;utf-8&quot; /&gt; &lt;link href=&quot;https://www.highcharts.com/highslide/highslide.css&quot; rel=&quot;stylesheet&quot; /&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js&quot;&gt;&lt;/script&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/highcharts.js&quot;&gt;&lt;/script&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/highcharts-more.js&quot;&gt;&lt;/script&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/modules/heatmap.js&quot;&gt;&lt;/script&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/modules/exporting.js&quot;&gt;&lt;/script&gt; &lt;/head&gt; &lt;body style=&quot;margin:0;padding:0&quot;&gt; &lt;div id=&quot;container&quot; style=&quot;width:650px;height:3555px;&quot;&gt;Loading....&lt;/div&gt; &lt;script&gt; $(function(){ Highcharts.setOptions({&quot;lang&quot;: {}, &quot;global&quot;: {}}); var option = {&quot;series&quot;: {}, &quot;exporting&quot;: {}, &quot;plotOptions&quot;: {&quot;boxplot&quot;: {&quot;color&quot;: &quot;#666&quot;}}, &quot;labels&quot;: {}, &quot;tooltip&quot;: {&quot;valueDecimals&quot;: 1, &quot;useHTML&quot;: true, &quot;footerFormat&quot;: &quot;&lt;/table&gt;&quot;, &quot;pointFormat&quot;: &quot;\n &lt;tr&gt;\n &lt;td style=\&quot;padding-right:0.5em\&quot;&gt;10th&lt;/td&gt;\n &lt;td style=\&quot;text-align:right\&quot;&gt;{point.low} min&lt;/td&gt;\n &lt;/tr&gt;\n &lt;tr&gt;\n &lt;td style=\&quot;padding-right:0.5em\&quot;&gt;25th&lt;/td&gt;\n &lt;td style=\&quot;text-align:right\&quot;&gt;{point.q1} min&lt;/td&gt;\n &lt;/tr&gt;\n &lt;tr&gt;\n &lt;td style=\&quot;padding-right:0.5em\&quot;&gt;50th&lt;/td&gt;\n &lt;td style=\&quot;text-align:right\&quot;&gt;{point.median} min&lt;/td&gt;\n &lt;/tr&gt;\n &lt;tr&gt;\n &lt;td style=\&quot;padding-right:0.5em\&quot;&gt;75th&lt;/td&gt;\n &lt;td style=\&quot;text-align:right\&quot;&gt;{point.q3} min&lt;/td&gt;\n &lt;/tr&gt;\n &lt;tr&gt;\n &lt;td style=\&quot;padding-right:0.5em\&quot;&gt;90th&lt;/td&gt;\n &lt;td style=\&quot;text-align:right\&quot;&gt;{point.high} min&lt;/td&gt;\n &lt;/tr&gt;\n &quot;, &quot;headerFormat&quot;: &quot;\n &lt;b&gt;{point.key}&lt;/b&gt; \n &lt;table&gt;&lt;tr&gt;&lt;td&gt;Percentile&lt;/td&gt;&lt;td&gt;Delay&lt;/td&gt;&lt;/tr&gt;\n &quot;}, &quot;navigation&quot;: {}, &quot;credits&quot;: {&quot;enabled&quot;: false}, &quot;colors&quot;: {}, &quot;xAxis&quot;: {&quot;title&quot;: {&quot;text&quot;: &quot;Route&quot;}, &quot;type&quot;: &quot;category&quot;, &quot;categories&quot;: [&quot;005, Britomart To Pt Chevalier Via Westmere&quot;, &quot;007, Pt Chevalier To Glen Innes&quot;, &quot;008, Otahuhu To New Lynn&quot;, &quot;009, Sylvia Park To New Lynn (No Stop On Donavon St By Countdown)&quot;, &quot;010, Wynyard Quarter To Onehunga Via Unitec&quot;, &quot;011, St Lukes to Onehunga&quot;, &quot;020, Britomart To Westmere Via Wellington St&quot;, &quot;020X, Britomart To Westmere Express&quot;, &quot;027, Stanmore Bay To Long Bay&quot;, &quot;030, Pt Chevalier To City Centre&quot;, &quot;046, St Josephs To Silverdale Express&quot;, &quot;048, City Centre To Te Atatu Peninsula Complete Loop&quot;, &quot;049, Henderson to City Centre Via Te Atatu Peninsula&quot;, &quot;04X, Te Atatu Peninsula To City Centre Express&quot;, &quot;060, Westgate To Helensville&quot;, &quot;070, Westgate To City Centre via Waimumu Road&quot;, &quot;079, Sturges Road To City Centre Via Sunnyvale&quot;, &quot;07X, City Centre To Parrs Park Express Via Te Atatu South&quot;, &quot;080, City Centre To Westgate&quot;, &quot;081, Westgate To City Centre Via Don Buck Rd&quot;, &quot;082, Te Atatu Shops To Westgate Shopping Centre&quot;, &quot;085, City Centre To Swanso ...
