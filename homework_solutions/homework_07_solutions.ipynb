# %%
from ggplot import *
# %matplotlib inline

# %%
ggplot(diamonds, aes(x='price', color='clarity')) + \
    geom_density() + \
    scale_color_brewer(type='div', palette=7) + \
    facet_wrap('cut')
# Out:
# <ggplot: (8754831182456)>
